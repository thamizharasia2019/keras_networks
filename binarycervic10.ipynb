# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import SGD
from keras.utils import np_utils
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import argparse
import cv2
import os
import math
import keras
from keras.layers import Dense,GlobalAveragePooling2D
from keras.preprocessing import image
from keras.models import Model
from keras.optimizers import Adam
from keras.applications import ResNet50


from keras.applications import imagenet_utils
from keras.preprocessing.image import load_img,img_to_array
from keras.preprocessing.image import load_img

from keras.callbacks import ModelCheckpoint
from keras.applications.imagenet_utils import preprocess_input


from keras.callbacks import LearningRateScheduler

from keras_radam import RAdam

from pyimagesearch.learningratefinder import LearningRateFinder
#from pyimagesearch import config
from pyimagesearch.clr_callback import CyclicLR
from keras import backend as K

import sys
from imutils import paths
# Out:
# Using TensorFlow backend.

# %%
# # construct the argument parser and parse the arguments
# ap = argparse.ArgumentParser()
# ap.add_argument("-d", "--dataset", required=True,
# 	help="path to input dataset")
# #ap.add_argument("-a", "--augment", type=int, default=-1,
# #	help="whether or not 'on the fly' data augmentation should be used")
# #ap.add_argument("-p", "--plot", type=str, default="plot.png",
# #	help="path to output loss/accuracy plot")
# args = vars(ap.parse_args())
# # # Using Resnet50 and initialised with weights of imagenet
# # ## images in smear 2005 are resized to 224 x224 





# grab the list of images in our dataset directory, then initialize
# the list of data (i.e., images) and class images
print("[INFO] loading images...")
#imagePaths = list(paths.list_images(args["dataset"]))
imagePaths = list(paths.list_images('./dataset_binary/'))
#print(imagePaths)
data = []
labels = []
 
# loop over the image paths
for imagePath in imagePaths:
	# extract the class label from the filename, load the image, and
	# resize it to be a fixed 64x64 pixels, ignoring aspect ratio
	label = imagePath.split(os.path.sep)[-2]
	#image = load_img(imagePath, target_size=(224, 224))
        # convert the image pixels to a numpy array
	#image = img_to_array(image)
        # reshape data for the model
	#image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
	image = cv2.imread(imagePath,1)
	image = cv2.resize(image, (224, 224))
	image= preprocess_input(image)
	# update the data and labels lists, respectively
	data.append(image)
	
	labels.append(label)


#print(imagePaths)
# Out:
# [INFO] loading images...

# %%
data = np.array(data, dtype="float") 
print('loaded data')
print(data.shape)
#print(len(data))
#print(len(labels))
# one-hot encode them
le = LabelEncoder()
labels = le.fit_transform(labels)
labels = np_utils.to_categorical(labels, 2)
# Out:
# loaded data
# (917, 224, 224, 3)

# %%
# convert the data into a NumPy array, then preprocess it by scaling
# all pixel intensities to the range [0, 1]
#data = np.array(data, dtype="float") / 255.0
 
# encode the labels (which are currently strings) as integers and then

 
# partition the data into training and testing splits using 75% of
# the data for training and the remaining 25% for testing
(trainX, testX, trainY, testY) = train_test_split(data, labels,
	test_size=0.20, random_state=10, shuffle=True)

# %%
# Resnet initialisation with imagenet

img_height,img_width = 224,224
num_classes = 2
input_shape= (img_height,img_width,3)
#base_model=ResNet50(weights='imagenet',include_top=False,input_shape= (img_height,img_width,3)) #imports the mobilenet model and discards the 

restnet = ResNet50(include_top=False, weights='imagenet', input_shape= (img_height,img_width,3))


output = restnet.layers[-1].output
output = keras.layers.Flatten()(output)

preds=Dense(num_classes,activation='softmax')(output ) #final layer with softmax activatio

model = Model(inputs=restnet.input, outputs=preds)
# Out:
# /home/thamizharasi/anaconda3/lib/python3.7/site-packages/keras_applications/resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '

# %%
# Freeze the layers except the last 4 layers
for layer in restnet.layers[:-3]:
    layer.trainable = False

# %%
#model.summary()

# %%
# ## Created function to computer F1 SCORE



def recall_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

def precision_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

def f1(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
# ## Compiled model using Adam optimizer and computed accuracy and f1 score

print("[INFO] compiling model...")
#opt = SGD(lr=INIT_LR, momentum=0.9, decay=INIT_LR / EPOCHS)

# optimiser intitialisation



#decay_rate = INIT_LR 
#decay_rate = INIT_LR / EPOCHS 

# learning rate schedule

# initial_lrate = 0.1
# drop = 0.5
# epochs_drop = 10.0

# def step_decay(epoch):
# 	#lrrate = math.floor(initial_lrate/3.0)    
# 	lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
# 	#decay_rate.append(lrrate)
# 	return lrate
 

#learning_rate=0.1
#decay_rate=learning_rate/ 3

#opt = keras.optimizers.Adam(lr=0.1, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=decay_rate)
# Out:
# [INFO] compiling model...

# %%
# data augmentation

train_datagen = ImageDataGenerator(
       
       # preprocessing_function=preprocess_input,
        
        adaptive_equalization=True, 
        histogram_equalization=True,
        rotation_range=90,
        #brightness_range=[0.5,2],
        width_shift_range=0.1,
        height_shift_range=0.1,
        
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='nearest')

# %%
MIN_LR = 1e-4
MAX_LR = 1e-3
BATCH_SIZE = 16
STEP_SIZE = 8
CLR_METHOD = "triangular"
NUM_EPOCHS = 5
CLASSES=['abnormal','normal']


# define the path to the output learning rate finder plot, training
# history plot and cyclical learning rate plot
LRFIND_PLOT_PATH = os.path.sep.join(["output", "lrfind_plot.png"])
TRAINING_PLOT_PATH = os.path.sep.join(["output", "training_loss.png"])
TRAINING_PLOT_ACC_PATH = os.path.sep.join(["output", "training_acc.png"])
CLR_PLOT_PATH = os.path.sep.join(["output", "clr_plot.png"])

# %%
opt = keras.optimizers.Adam(lr=0.1)
model.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['accuracy',f1])

# %%
rate=0
if rate!=1:
	print("[INFO] finding learning rate...")
	lrf = LearningRateFinder(model)
	lrf.find(
		train_datagen.flow(trainX, trainY, batch_size=BATCH_SIZE),
		1e-12, 1e+1,epochs=5,
		stepsPerEpoch=np.ceil((len(trainX) / float(BATCH_SIZE))),
		batchSize=BATCH_SIZE)
	 
		# plot the loss for the various learning rates and save the
		# resulting plot to disk
	lrf.plot_loss()
	plt.savefig(LRFIND_PLOT_PATH)
	print("[INFO] learning rate finder complete")
	print("[INFO] examine plot and adjust learning rates before training")
	#sys.exit(0)
# Out:
# [INFO] finding learning rate...
# Epoch 1/5
# 46/46 [==============================] - 63s 1s/step - loss: 1.6058 - accuracy: 0.4175 - f1: 0.4176
# Epoch 2/5
# 46/46 [==============================] - 63s 1s/step - loss: 1.5712 - accuracy: 0.4352 - f1: 0.4353
# Epoch 3/5
# 46/46 [==============================] - 63s 1s/step - loss: 1.2964 - accuracy: 0.5184 - f1: 0.5194
# Epoch 4/5
# 46/46 [==============================] - 63s 1s/step - loss: 2.2179 - accuracy: 0.7763 - f1: 0.7765
# Epoch 5/5
# 11/46 [======>.......................] - ETA: 49s - loss: 14.7272 - accuracy: 0.8239 - f1: 0.8239[INFO] learning rate finder complete
# [INFO] examine plot and adjust learning rates before training

# %%
# hyperparameter tuning
import math
stepSize = STEP_SIZE * (trainX.shape[0] // BATCH_SIZE)
clr = CyclicLR(
	mode=CLR_METHOD,
	base_lr=MIN_LR,
	max_lr=MAX_LR,
	step_size=stepSize)

opt = keras.optimizers.Adam(lr=0.1)
model.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['accuracy',f1])


# initial rate is set based on learning rate finder max value
initial_lrate=1e-1
def time_decay(EPOCHS, initial_lrate):
    decay_rate = 0.1
    new_lrate = initial_lrate/(1+decay_rate*EPOCHS)
    return new_lrate

initial_lrate=1e-1
def time_decay1(EPOCHS, initial_lrate):
    decay_rate = 0.1
    epochs_drop=5.0
    new_lrate = initial_lrate/(1+decay_rate*math.floor((1+EPOCHS)/epochs_drop) )
    return new_lrate

def step_decay(EPOCHS):
    initial_lrate=1e-1
    drop=0.5
    epochs_drop=3.0
    new_lrate=initial_lrate*math.pow(drop,math.floor((1+EPOCHS)/epochs_drop))
    return new_lrate

from keras.callbacks import LearningRateScheduler
lrate = LearningRateScheduler(time_decay,verbose=1)

lrate1 = LearningRateScheduler(step_decay,verbose=1)

lrate2 = LearningRateScheduler(time_decay1,verbose=1)


filepath=" Adam 0.1 binary weights-improvement-{epoch:02d}-{val_accuracy:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

#early = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=1e-4, patience=10)
reduce1 = keras.callbacks.ReduceLROnPlateau(monitor='val_accuracy', verbose=1,factor= 0.33, patience=1,min_lr=1e-4)


#lrate = LearningRateScheduler(step_decay, verbose=1)


#callbacks_list = [checkpoint,early,reduce1]

#callbacks_list = [checkpoint,reduce1,lrate]

#callbacks_list = [checkpoint,reduce1]


callbacks_list = [checkpoint,lrate2]





#validation_generator = val_datagen.flow(testX, testY)

# %%
EPOCHS = 50
print("[INFO] training network...")
H = model.fit_generator(
	train_datagen.flow(trainX, trainY, batch_size=BATCH_SIZE),
	validation_data=(testX, testY),
	steps_per_epoch=trainX.shape[0] // BATCH_SIZE,
	epochs=EPOCHS,
	callbacks=callbacks_list,
	verbose=2)



#INIT_LR = 1e-1
#BS = 64
# Out:
# [INFO] training network...
# Epoch 1/50
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.10000000149011612.
#  - 80s - loss: 370.6977 - accuracy: 0.7824 - f1: 0.7827 - val_loss: 186.9140 - val_accuracy: 0.9022 - val_f1: 0.9010
#
# Epoch 00001: val_accuracy improved from -inf to 0.90217, saving model to  Adam 0.1 binary weights-improvement-01-0.90.hdf5
# Epoch 2/50
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.10000000149011612.
#  - 79s - loss: 115.2239 - accuracy: 0.8550 - f1: 0.8549 - val_loss: 139.6664 - val_accuracy: 0.8859 - val_f1: 0.8923
#
# Epoch 00002: val_accuracy did not improve from 0.90217
# Epoch 3/50
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.10000000149011612.
#  - 79s - loss: 91.6032 - accuracy: 0.8577 - f1: 0.8580 - val_loss: 144.5794 - val_accuracy: 0.8804 - val_f1: 0.8698
#
# Epoch 00003: val_accuracy did not improve from 0.90217
# Epoch 4/50
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.10000000149011612.
#  - 79s - loss: 73.6901 - accuracy: 0.8801 - f1: 0.8796 - val_loss: 202.2770 - val_accuracy: 0.8804 - val_f1: 0.8750
#
# Epoch 00004: val_accuracy did not improve from 0.90217
# Epoch 5/50
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.09090909226374191.
#  - 79s - loss: 91.0389 - accuracy: 0.8647 - f1: 0.8646 - val_loss: 278.7569 - val_accuracy: 0.8696 - val_f1: 0.8646
#
# Epoch 00005: val_accuracy did not improve from 0.90217
# Epoch 6/50
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.0826446305621754.
#  - 78s - loss: 104.9675 - accuracy: 0.8605 - f1: 0.8601 - val_loss: 305.4796 - val_accuracy: 0.8533 - val_f1: 0.8490
#
# Epoch 00006: val_accuracy did not improve from 0.90217
# Epoch 7/50
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.07513148540800267.
#  - 79s - loss: 98.2809 - accuracy: 0.8889 - f1: 0.8889 - val_loss: 163.0306 - val_accuracy: 0.8967 - val_f1: 0.8906
#
# Epoch 00007: val_accuracy did not improve from 0.90217
# Epoch 8/50
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.06830134852366014.
#  - 78s - loss: 59.1390 - accuracy: 0.9079 - f1: 0.9077 - val_loss: 141.9295 - val_accuracy: 0.9130 - val_f1: 0.9115
#
# Epoch 00008: val_accuracy improved from 0.90217 to 0.91304, saving model to  Adam 0.1 binary weights-improvement-08-0.91.hdf5
# Epoch 9/50
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.06209213625301014.
#  - 78s - loss: 63.0456 - accuracy: 0.8978 - f1: 0.8980 - val_loss: 148.9658 - val_accuracy: 0.8913 - val_f1: 0.8906
#
# Epoch 00009: val_accuracy did not improve from 0.91304
# Epoch 10/50
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.05174344715972742.
#  - 78s - loss: 47.4523 - accuracy: 0.9083 - f1: 0.9083 - val_loss: 84.0968 - val_accuracy: 0.8913 - val_f1: 0.8906
#
# Epoch 00010: val_accuracy did not improve from 0.91304
# Epoch 11/50
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.04311953981717428.
#  - 78s - loss: 43.3354 - accuracy: 0.9090 - f1: 0.9094 - val_loss: 124.1119 - val_accuracy: 0.8859 - val_f1: 0.8802
#
# Epoch 00011: val_accuracy did not improve from 0.91304
# Epoch 12/50
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.03593294881284237.
#  - 78s - loss: 41.0844 - accuracy: 0.9275 - f1: 0.9278 - val_loss: 100.4907 - val_accuracy: 0.8913 - val_f1: 0.8854
#
# Epoch 00012: val_accuracy did not improve from 0.91304
# Epoch 13/50
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.029944125562906265.
#  - 78s - loss: 45.3956 - accuracy: 0.9093 - f1: 0.9091 - val_loss: 138.9863 - val_accuracy: 0.8804 - val_f1: 0.8750
#
# Epoch 00013: val_accuracy did not improve from 0.91304
# Epoch 14/50
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.024953437969088554.
#  - 82s - loss: 48.9496 - accuracy: 0.9181 - f1: 0.9181 - val_loss: 99.5991 - val_accuracy: 0.8913 - val_f1: 0.8906
#
# Epoch 00014: val_accuracy did not improve from 0.91304
# Epoch 15/50
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.019194952283914272.
#  - 79s - loss: 41.6818 - accuracy: 0.9104 - f1: 0.9111 - val_loss: 74.6803 - val_accuracy: 0.9022 - val_f1: 0.9010
#
# Epoch 00015: val_accuracy did not improve from 0.91304
# Epoch 16/50
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.014765348571997423.
#  - 79s - loss: 41.5718 - accuracy: 0.9181 - f1: 0.9181 - val_loss: 84.9597 - val_accuracy: 0.9022 - val_f1: 0.9010
#
# Epoch 00016: val_accuracy did not improve from 0.91304
# Epoch 17/50
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.011357960219566638.
#  - 80s - loss: 29.9285 - accuracy: 0.9244 - f1: 0.9250 - val_loss: 83.4859 - val_accuracy: 0.9076 - val_f1: 0.9062
#
# Epoch 00017: val_accuracy did not improve from 0.91304
# Epoch 18/50
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.008736892531697566.
#  - 80s - loss: 30.0131 - accuracy: 0.9194 - f1: 0.9194 - val_loss: 65.1923 - val_accuracy: 0.8913 - val_f1: 0.8854
#
# Epoch 00018: val_accuracy did not improve from 0.91304
# Epoch 19/50
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.006720686617952126.
#  - 79s - loss: 33.7273 - accuracy: 0.9289 - f1: 0.9292 - val_loss: 74.3529 - val_accuracy: 0.9076 - val_f1: 0.9062
#
# Epoch 00019: val_accuracy did not improve from 0.91304
# Epoch 20/50
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.004800490569323301.
#  - 79s - loss: 19.6248 - accuracy: 0.9442 - f1: 0.9441 - val_loss: 80.0604 - val_accuracy: 0.9076 - val_f1: 0.9062
#
# Epoch 00020: val_accuracy did not improve from 0.91304
# Epoch 21/50
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.0034289218352309297.
#  - 79s - loss: 35.4911 - accuracy: 0.9289 - f1: 0.9288 - val_loss: 74.5411 - val_accuracy: 0.9130 - val_f1: 0.9115
#
# Epoch 00021: val_accuracy did not improve from 0.91304
# Epoch 22/50
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.002449229858549578.
#  - 79s - loss: 33.8418 - accuracy: 0.9160 - f1: 0.9163 - val_loss: 74.9011 - val_accuracy: 0.9130 - val_f1: 0.9115
#
# Epoch 00022: val_accuracy did not improve from 0.91304
# Epoch 23/50
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.0017494498752057555.
#  - 78s - loss: 33.5063 - accuracy: 0.9275 - f1: 0.9275 - val_loss: 67.9488 - val_accuracy: 0.9022 - val_f1: 0.8958
#
# Epoch 00023: val_accuracy did not improve from 0.91304
# Epoch 24/50
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.0012496070537183967.
#  - 81s - loss: 34.5315 - accuracy: 0.9331 - f1: 0.9327 - val_loss: 69.4654 - val_accuracy: 0.9022 - val_f1: 0.8958
#
# Epoch 00024: val_accuracy did not improve from 0.91304
# Epoch 25/50
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.0008330713802327713.
#  - 79s - loss: 25.3244 - accuracy: 0.9261 - f1: 0.9261 - val_loss: 69.2106 - val_accuracy: 0.9022 - val_f1: 0.8958
#
# Epoch 00025: val_accuracy did not improve from 0.91304
# Epoch 26/50
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.0005553809072201451.
#  - 79s - loss: 34.2972 - accuracy: 0.9233 - f1: 0.9230 - val_loss: 69.3697 - val_accuracy: 0.9022 - val_f1: 0.8958
#
# Epoch 00026: val_accuracy did not improve from 0.91304
# Epoch 27/50
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.0003702539252117276.
#  - 79s - loss: 28.7765 - accuracy: 0.9275 - f1: 0.9278 - val_loss: 69.3996 - val_accuracy: 0.9022 - val_f1: 0.8958
#
# Epoch 00027: val_accuracy did not improve from 0.91304
# Epoch 28/50
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.00024683595014115173.
#  - 80s - loss: 28.9131 - accuracy: 0.9319 - f1: 0.9319 - val_loss: 69.2611 - val_accuracy: 0.9022 - val_f1: 0.8958
#
# Epoch 00028: val_accuracy did not improve from 0.91304
# Epoch 29/50
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.00016455730656161904.
#  - 78s - loss: 29.4191 - accuracy: 0.9216 - f1: 0.9216 - val_loss: 68.9699 - val_accuracy: 0.9022 - val_f1: 0.8958
#
# Epoch 00029: val_accuracy did not improve from 0.91304
# Epoch 30/50
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.0001028483166010119.
#  - 78s - loss: 17.0332 - accuracy: 0.9554 - f1: 0.9556 - val_loss: 69.3041 - val_accuracy: 0.9022 - val_f1: 0.8958
#
# Epoch 00030: val_accuracy did not improve from 0.91304
# Epoch 31/50
#
# Epoch 00031: LearningRateScheduler setting learning rate to 6.428019787563244e-05.
#  - 79s - loss: 31.7316 - accuracy: 0.9125 - f1: 0.9125 - val_loss: 69.2638 - val_accuracy: 0.9022 - val_f1: 0.8958
#
# Epoch 00031: val_accuracy did not improve from 0.91304
# Epoch 32/50
#
# Epoch 00032: LearningRateScheduler setting learning rate to 4.0175123103836086e-05.
#  - 78s - loss: 32.0403 - accuracy: 0.9303 - f1: 0.9299 - val_loss: 69.1786 - val_accuracy: 0.9022 - val_f1: 0.8958
#
# Epoch 00032: val_accuracy did not improve from 0.91304
# Epoch 33/50
#
# Epoch 00033: LearningRateScheduler setting learning rate to 2.5109452508331742e-05.
#  - 78s - loss: 27.2537 - accuracy: 0.9400 - f1: 0.9400 - val_loss: 69.1982 - val_accuracy: 0.9022 - val_f1: 0.8958
#
# Epoch 00033: val_accuracy did not improve from 0.91304
# Epoch 34/50
#
# Epoch 00034: LearningRateScheduler setting learning rate to 1.5693408386141527e-05.
#  - 78s - loss: 28.4763 - accuracy: 0.9275 - f1: 0.9271 - val_loss: 69.1162 - val_accuracy: 0.9022 - val_f1: 0.8958
#
# Epoch 00034: val_accuracy did not improve from 0.91304
# Epoch 35/50
#
# Epoch 00035: LearningRateScheduler setting learning rate to 9.231416162733427e-06.
#  - 78s - loss: 29.9901 - accuracy: 0.9342 - f1: 0.9344 - val_loss: 69.0161 - val_accuracy: 0.9022 - val_f1: 0.8958
#
# Epoch 00035: val_accuracy did not improve from 0.91304
# Epoch 36/50
#
# Epoch 00036: LearningRateScheduler setting learning rate to 5.430244581315063e-06.
#  - 79s - loss: 25.4660 - accuracy: 0.9347 - f1: 0.9347 - val_loss: 69.1171 - val_accuracy: 0.9022 - val_f1: 0.8958
#
# Epoch 00036: val_accuracy did not improve from 0.91304
# Epoch 37/50
#
# Epoch 00037: LearningRateScheduler setting learning rate to 3.1942614869502205e-06.
#  - 79s - loss: 28.6493 - accuracy: 0.9317 - f1: 0.9313 - val_loss: 68.9957 - val_accuracy: 0.9022 - val_f1: 0.8958
#
# Epoch 00037: val_accuracy did not improve from 0.91304
# Epoch 38/50
#
# Epoch 00038: LearningRateScheduler setting learning rate to 1.8789774003380442e-06.
#  - 78s - loss: 36.9210 - accuracy: 0.9149 - f1: 0.9150 - val_loss: 69.0287 - val_accuracy: 0.9022 - val_f1: 0.8958
#
# Epoch 00038: val_accuracy did not improve from 0.91304
# Epoch 39/50
#
# Epoch 00039: LearningRateScheduler setting learning rate to 1.1052808237282614e-06.
#  - 78s - loss: 40.6783 - accuracy: 0.9121 - f1: 0.9119 - val_loss: 69.0160 - val_accuracy: 0.9022 - val_f1: 0.8958
#
# Epoch 00039: val_accuracy did not improve from 0.91304
# Epoch 40/50
#
# Epoch 00040: LearningRateScheduler setting learning rate to 6.140449057865125e-07.
#  - 1042s - loss: 15.0833 - accuracy: 0.9554 - f1: 0.9556 - val_loss: 69.1413 - val_accuracy: 0.9022 - val_f1: 0.8958
#
# Epoch 00040: val_accuracy did not improve from 0.91304
# Epoch 41/50
#
# Epoch 00041: LearningRateScheduler setting learning rate to 3.411360517525787e-07.
#  - 80s - loss: 27.2731 - accuracy: 0.9358 - f1: 0.9355 - val_loss: 69.1488 - val_accuracy: 0.9022 - val_f1: 0.8958
#
# Epoch 00041: val_accuracy did not improve from 0.91304
# Epoch 42/50
#
# Epoch 00042: LearningRateScheduler setting learning rate to 1.895200322602856e-07.
#  - 81s - loss: 40.8533 - accuracy: 0.9261 - f1: 0.9257 - val_loss: 69.0749 - val_accuracy: 0.9022 - val_f1: 0.8958
#
# Epoch 00042: val_accuracy did not improve from 0.91304
# Epoch 43/50
#
# Epoch 00043: LearningRateScheduler setting learning rate to 1.0528890944290954e-07.
#  - 80s - loss: 27.3367 - accuracy: 0.9386 - f1: 0.9382 - val_loss: 69.0874 - val_accuracy: 0.9022 - val_f1: 0.8958
#
# Epoch 00043: val_accuracy did not improve from 0.91304
# Epoch 44/50
#
# Epoch 00044: LearningRateScheduler setting learning rate to 5.849383989521407e-08.
#  - 80s - loss: 37.5802 - accuracy: 0.9275 - f1: 0.9278 - val_loss: 69.1993 - val_accuracy: 0.9022 - val_f1: 0.8958
#
# Epoch 00044: val_accuracy did not improve from 0.91304
# Epoch 45/50
#
# Epoch 00045: LearningRateScheduler setting learning rate to 3.078623110827481e-08.
#  - 83s - loss: 22.5496 - accuracy: 0.9386 - f1: 0.9389 - val_loss: 69.0774 - val_accuracy: 0.9022 - val_f1: 0.8958
#
# Epoch 00045: val_accuracy did not improve from 0.91304
# Epoch 46/50
#
# Epoch 00046: LearningRateScheduler setting learning rate to 1.6203280121149683e-08.
#  - 80s - loss: 30.1929 - accuracy: 0.9372 - f1: 0.9369 - val_loss: 69.0544 - val_accuracy: 0.9022 - val_f1: 0.8958
#
# Epoch 00046: val_accuracy did not improve from 0.91304
# Epoch 47/50
#
# Epoch 00047: LearningRateScheduler setting learning rate to 8.528042365852392e-09.
#  - 79s - loss: 30.5741 - accuracy: 0.9372 - f1: 0.9372 - val_loss: 69.0096 - val_accuracy: 0.9022 - val_f1: 0.8958
#
# Epoch 00047: val_accuracy did not improve from 0.91304
# Epoch 48/50
#
# Epoch 00048: LearningRateScheduler setting learning rate to 4.488443301242066e-09.
#  - 80s - loss: 26.8222 - accuracy: 0.9331 - f1: 0.9327 - val_loss: 69.1727 - val_accuracy: 0.9022 - val_f1: 0.8958
#
# Epoch 00048: val_accuracy did not improve from 0.91304
# Epoch 49/50
#
# Epoch 00049: LearningRateScheduler setting learning rate to 2.3623386288076483e-09.
#  - 79s - loss: 30.7573 - accuracy: 0.9289 - f1: 0.9292 - val_loss: 69.2568 - val_accuracy: 0.9022 - val_f1: 0.8958
#
# Epoch 00049: val_accuracy did not improve from 0.91304
# Epoch 50/50
#
# Epoch 00050: LearningRateScheduler setting learning rate to 1.1811692735008705e-09.
#  - 80s - loss: 26.4592 - accuracy: 0.9247 - f1: 0.9244 - val_loss: 69.1387 - val_accuracy: 0.9022 - val_f1: 0.8958
#
# Epoch 00050: val_accuracy did not improve from 0.91304

# %%
# evaluate the network and show a classification report
print("[INFO] evaluating network...")
predictions = model.predict(testX, batch_size=BATCH_SIZE)
print(classification_report(testY.argmax(axis=1),
	predictions.argmax(axis=1), target_names=CLASSES))
# Out:
# [INFO] evaluating network...
#               precision    recall  f1-score   support
#
#     abnormal       0.91      0.97      0.94       138
#       normal       0.89      0.70      0.78        46
#
#     accuracy                           0.90       184
#    macro avg       0.90      0.83      0.86       184
# weighted avg       0.90      0.90      0.90       184

# %%
# construct a plot that plots and saves the training history
N = np.arange(0, EPOCHS)
plt.style.use("ggplot")
plt.figure()
plt.plot(N, H.history["loss"], label="train_loss")
plt.plot(N, H.history["val_loss"], label="val_loss")
#plt.plot(N, H.history["accuracy"], label="train_acc")
#plt.plot(N, H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss ")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend(loc="lower left")
plt.savefig(TRAINING_PLOT_PATH)

# %%
# construct a plot that plots and saves the training history
N = np.arange(0, EPOCHS)
plt.style.use("ggplot")
plt.figure()
#plt.plot(N, H.history["loss"], label="train_loss")
#plt.plot(N, H.history["val_loss"], label="val_loss")
plt.plot(N, H.history["accuracy"], label="train_acc")
plt.plot(N, H.history["val_accuracy"], label="val_acc")
plt.title("Training Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Accuracy")
plt.legend(loc="lower left")
plt.savefig(TRAINING_PLOT_ACC_PATH)

# %%
# # plot the learning rate history
# N = np.arange(0, len(clr.history["lr"]))
# plt.figure()
# plt.plot(N, clr.history["lr"])
# plt.title("Cyclical Learning Rate (CLR)")
# plt.xlabel("Training Iterations")
# plt.ylabel("Learning Rate")
# plt.savefig(CLR_PLOT_PATH)
