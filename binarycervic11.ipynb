# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import SGD
from keras.utils import np_utils
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import argparse
import cv2
import os
import math
import keras
from keras.layers import Dense,GlobalAveragePooling2D
from keras.preprocessing import image
from keras.models import Model
from keras.optimizers import Adam
from keras.applications import ResNet50


from keras.applications import imagenet_utils
from keras.preprocessing.image import load_img,img_to_array
from keras.preprocessing.image import load_img

from keras.callbacks import ModelCheckpoint
from keras.applications.imagenet_utils import preprocess_input


from keras.callbacks import LearningRateScheduler

from keras_radam import RAdam

from pyimagesearch.learningratefinder import LearningRateFinder
#from pyimagesearch import config
from pyimagesearch.clr_callback import CyclicLR
from keras import backend as K

import sys
from imutils import paths

# %%
# # construct the argument parser and parse the arguments
# ap = argparse.ArgumentParser()
# ap.add_argument("-d", "--dataset", required=True,
# 	help="path to input dataset")
# #ap.add_argument("-a", "--augment", type=int, default=-1,
# #	help="whether or not 'on the fly' data augmentation should be used")
# #ap.add_argument("-p", "--plot", type=str, default="plot.png",
# #	help="path to output loss/accuracy plot")
# args = vars(ap.parse_args())
# # # Using Resnet50 and initialised with weights of imagenet
# # ## images in smear 2005 are resized to 224 x224 





# grab the list of images in our dataset directory, then initialize
# the list of data (i.e., images) and class images
print("[INFO] loading images...")
#imagePaths = list(paths.list_images(args["dataset"]))
imagePaths = list(paths.list_images('./dataset_binary/'))
#print(imagePaths)
data = []
labels = []
 
# loop over the image paths
for imagePath in imagePaths:
	# extract the class label from the filename, load the image, and
	# resize it to be a fixed 64x64 pixels, ignoring aspect ratio
	label = imagePath.split(os.path.sep)[-2]
	#image = load_img(imagePath, target_size=(224, 224))
        # convert the image pixels to a numpy array
	#image = img_to_array(image)
        # reshape data for the model
	#image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
	image = cv2.imread(imagePath,1)
	image = cv2.resize(image, (224, 224))
	image= preprocess_input(image)
	# update the data and labels lists, respectively
	data.append(image)
	
	labels.append(label)


#print(imagePaths)
# Out:
# [INFO] loading images...

# %%
data = np.array(data, dtype="float") 
print('loaded data')
print(data.shape)
#print(len(data))
#print(len(labels))
# one-hot encode them
le = LabelEncoder()
labels = le.fit_transform(labels)
labels = np_utils.to_categorical(labels, 2)
# Out:
# loaded data
# (917, 224, 224, 3)

# %%
# convert the data into a NumPy array, then preprocess it by scaling
# all pixel intensities to the range [0, 1]
#data = np.array(data, dtype="float") / 255.0
 
# encode the labels (which are currently strings) as integers and then

 
# partition the data into training and testing splits using 75% of
# the data for training and the remaining 25% for testing
(trainX, testX, trainY, testY) = train_test_split(data, labels,
	test_size=0.20, random_state=10, shuffle=True)

# %%
# Resnet initialisation with imagenet

img_height,img_width = 224,224
num_classes = 2
input_shape= (img_height,img_width,3)
#base_model=ResNet50(weights='imagenet',include_top=False,input_shape= (img_height,img_width,3)) #imports the mobilenet model and discards the 

restnet = ResNet50(include_top=False, weights='imagenet', input_shape= (img_height,img_width,3))


output = restnet.layers[-1].output
output = keras.layers.Flatten()(output)

preds=Dense(num_classes,activation='softmax')(output ) #final layer with softmax activatio

model = Model(inputs=restnet.input, outputs=preds)
# Out:
# /home/thamizharasi/anaconda3/lib/python3.7/site-packages/keras_applications/resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '

# %%
# Freeze the layers except the last 4 layers
for layer in restnet.layers[:-3]:
    layer.trainable = False

# %%
#model.summary()

# %%
# ## Created function to computer F1 SCORE



def recall_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

def precision_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

def f1(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
# ## Compiled model using Adam optimizer and computed accuracy and f1 score

print("[INFO] compiling model...")
#opt = SGD(lr=INIT_LR, momentum=0.9, decay=INIT_LR / EPOCHS)

# optimiser intitialisation



#decay_rate = INIT_LR 
#decay_rate = INIT_LR / EPOCHS 

# learning rate schedule

# initial_lrate = 0.1
# drop = 0.5
# epochs_drop = 10.0

# def step_decay(epoch):
# 	#lrrate = math.floor(initial_lrate/3.0)    
# 	lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
# 	#decay_rate.append(lrrate)
# 	return lrate
 

#learning_rate=0.1
#decay_rate=learning_rate/ 3

#opt = keras.optimizers.Adam(lr=0.1, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=decay_rate)
# Out:
# [INFO] compiling model...

# %%
# data augmentation

train_datagen = ImageDataGenerator(
       
       # preprocessing_function=preprocess_input,
        
        adaptive_equalization=True, 
        histogram_equalization=True,
        rotation_range=90,
        #brightness_range=[0.5,2],
        width_shift_range=0.1,
        height_shift_range=0.1,
        
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='nearest')

# %%
MIN_LR = 1e-4
MAX_LR = 1e-3
BATCH_SIZE = 16
STEP_SIZE = 8
CLR_METHOD = "triangular"
NUM_EPOCHS = 5
CLASSES=['abnormal','normal']


# define the path to the output learning rate finder plot, training
# history plot and cyclical learning rate plot
LRFIND_PLOT_PATH = os.path.sep.join(["output", "lrfind_plot.png"])
TRAINING_PLOT_PATH = os.path.sep.join(["output", "training_loss.png"])
TRAINING_PLOT_ACC_PATH = os.path.sep.join(["output", "training_acc.png"])
CLR_PLOT_PATH = os.path.sep.join(["output", "clr_plot.png"])

# %%
opt = keras.optimizers.Adam(lr=0.1)
model.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['accuracy',f1])

# %%
rate=0
if rate!=1:
	print("[INFO] finding learning rate...")
	lrf = LearningRateFinder(model)
	lrf.find(
		train_datagen.flow(trainX, trainY, batch_size=BATCH_SIZE),
		1e-12, 1e+1,epochs=5,
		stepsPerEpoch=np.ceil((len(trainX) / float(BATCH_SIZE))),
		batchSize=BATCH_SIZE)
	 
		# plot the loss for the various learning rates and save the
		# resulting plot to disk
	lrf.plot_loss()
	plt.savefig(LRFIND_PLOT_PATH)
	print("[INFO] learning rate finder complete")
	print("[INFO] examine plot and adjust learning rates before training")
	#sys.exit(0)
# Out:
# [INFO] finding learning rate...
# Epoch 1/5
# 46/46 [==============================] - 62s 1s/step - loss: 1.7883 - accuracy: 0.3943 - f1: 0.3945
# Epoch 2/5
# 46/46 [==============================] - 62s 1s/step - loss: 1.6124 - accuracy: 0.4202 - f1: 0.4204
# Epoch 3/5
# 46/46 [==============================] - 62s 1s/step - loss: 1.3069 - accuracy: 0.5416 - f1: 0.5419
# Epoch 4/5
# 46/46 [==============================] - 62s 1s/step - loss: 2.5934 - accuracy: 0.7913 - f1: 0.7909
# Epoch 5/5
#  9/46 [====>.........................] - ETA: 51s - loss: 13.8332 - accuracy: 0.8125 - f1: 0.8125[INFO] learning rate finder complete
# [INFO] examine plot and adjust learning rates before training

# %%
# hyperparameter tuning
import math
stepSize = STEP_SIZE * (trainX.shape[0] // BATCH_SIZE)
clr = CyclicLR(
	mode=CLR_METHOD,
	base_lr=MIN_LR,
	max_lr=MAX_LR,
	step_size=stepSize)

opt = keras.optimizers.Adam(lr=0.1)
model.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['accuracy',f1])


# initial rate is set based on learning rate finder max value
initial_lrate=1e-1
def time_decay(EPOCHS, initial_lrate):
    decay_rate = 0.1
    new_lrate = initial_lrate/(1+decay_rate*EPOCHS)
    return new_lrate

initial_lrate=1e-1
def time_decay1(EPOCHS, initial_lrate):
    decay_rate = 0.1
    epochs_drop=5.0
    new_lrate = initial_lrate/(1+decay_rate*math.floor((1+EPOCHS)/epochs_drop) )
    return new_lrate

def time_decay2(EPOCHS, initial_lrate):
    #decay_rate = .01
    #epochs_drop=5.0
    new_lrate = initial_lrate - (initial_lrate /100)
    return new_lrate


def step_decay(EPOCHS):
    initial_lrate=1e-1
    drop=0.5
    epochs_drop=3.0
    new_lrate=initial_lrate*math.pow(drop,math.floor((1+EPOCHS)/epochs_drop))
    return new_lrate

from keras.callbacks import LearningRateScheduler
lrate = LearningRateScheduler(time_decay,verbose=1)

lrate1 = LearningRateScheduler(step_decay,verbose=1)

lrate2 = LearningRateScheduler(time_decay1,verbose=1)

lrate3 = LearningRateScheduler(time_decay2,verbose=1)


filepath=" Adam 0.1 binary weights-improvement-{epoch:02d}-{val_accuracy:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

#early = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=1e-4, patience=10)
reduce1 = keras.callbacks.ReduceLROnPlateau(monitor='val_accuracy', verbose=1,factor= 0.33, patience=1,min_lr=1e-4)


#lrate = LearningRateScheduler(step_decay, verbose=1)


#callbacks_list = [checkpoint,early,reduce1]

#callbacks_list = [checkpoint,reduce1,lrate]

#callbacks_list = [checkpoint,reduce1]


callbacks_list = [checkpoint,lrate3]





#validation_generator = val_datagen.flow(testX, testY)

# %%
EPOCHS = 50
print("[INFO] training network...")
H = model.fit_generator(
	train_datagen.flow(trainX, trainY, batch_size=BATCH_SIZE),
	validation_data=(testX, testY),
	steps_per_epoch=trainX.shape[0] // BATCH_SIZE,
	epochs=EPOCHS,
	callbacks=callbacks_list,
	verbose=2)



#INIT_LR = 1e-1
#BS = 64
# Out:
# [INFO] training network...
# Epoch 1/50
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.09605959564447403.
#  - 78s - loss: 93.7649 - accuracy: 0.8787 - f1: 0.8788 - val_loss: 151.7910 - val_accuracy: 0.8750 - val_f1: 0.8698
#
# Epoch 00001: val_accuracy improved from 0.85326 to 0.87500, saving model to  Adam 0.1 binary weights-improvement-01-0.88.hdf5
# Epoch 2/50
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.09509900204837322.
#  - 78s - loss: 63.4625 - accuracy: 0.9052 - f1: 0.9052 - val_loss: 226.7926 - val_accuracy: 0.8804 - val_f1: 0.8802
#
# Epoch 00002: val_accuracy improved from 0.87500 to 0.88043, saving model to  Adam 0.1 binary weights-improvement-02-0.88.hdf5
# Epoch 3/50
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.09414801210165023.
#  - 78s - loss: 69.7051 - accuracy: 0.8968 - f1: 0.8969 - val_loss: 175.7243 - val_accuracy: 0.8696 - val_f1: 0.8646
#
# Epoch 00003: val_accuracy did not improve from 0.88043
# Epoch 4/50
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.09320652991533279.
#  - 78s - loss: 101.7132 - accuracy: 0.8815 - f1: 0.8813 - val_loss: 268.5155 - val_accuracy: 0.8641 - val_f1: 0.8718
#
# Epoch 00004: val_accuracy did not improve from 0.88043
# Epoch 5/50
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0922744669765234.
#  - 78s - loss: 84.0220 - accuracy: 0.9024 - f1: 0.9021 - val_loss: 474.7550 - val_accuracy: 0.8478 - val_f1: 0.8437
#
# Epoch 00005: val_accuracy did not improve from 0.88043
# Epoch 6/50
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.09135172002017498.
#  - 78s - loss: 85.8255 - accuracy: 0.9093 - f1: 0.9094 - val_loss: 237.7909 - val_accuracy: 0.8750 - val_f1: 0.8698
#
# Epoch 00006: val_accuracy did not improve from 0.88043
# Epoch 7/50
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.09043820053339005.
#  - 78s - loss: 103.5305 - accuracy: 0.8536 - f1: 0.8538 - val_loss: 214.4507 - val_accuracy: 0.8804 - val_f1: 0.8750
#
# Epoch 00007: val_accuracy did not improve from 0.88043
# Epoch 8/50
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.0895338200032711.
#  - 78s - loss: 84.6675 - accuracy: 0.9121 - f1: 0.9125 - val_loss: 245.5924 - val_accuracy: 0.8913 - val_f1: 0.8802
#
# Epoch 00008: val_accuracy improved from 0.88043 to 0.89130, saving model to  Adam 0.1 binary weights-improvement-08-0.89.hdf5
# Epoch 9/50
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.08863848254084587.
#  - 77s - loss: 93.7176 - accuracy: 0.8944 - f1: 0.8944 - val_loss: 257.3757 - val_accuracy: 0.8859 - val_f1: 0.8802
#
# Epoch 00009: val_accuracy did not improve from 0.89130
# Epoch 10/50
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.08775209963321685.
#  - 77s - loss: 96.7234 - accuracy: 0.9104 - f1: 0.9108 - val_loss: 341.1958 - val_accuracy: 0.8859 - val_f1: 0.8854
#
# Epoch 00010: val_accuracy did not improve from 0.89130
# Epoch 11/50
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.08687457539141179.
#  - 77s - loss: 82.6306 - accuracy: 0.9135 - f1: 0.9136 - val_loss: 370.5285 - val_accuracy: 0.8750 - val_f1: 0.8646
#
# Epoch 00011: val_accuracy did not improve from 0.89130
# Epoch 12/50
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.08600582867860794.
#  - 77s - loss: 115.4632 - accuracy: 0.8870 - f1: 0.8869 - val_loss: 215.2455 - val_accuracy: 0.8913 - val_f1: 0.8974
#
# Epoch 00012: val_accuracy did not improve from 0.89130
# Epoch 13/50
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.08514577098190784.
#  - 77s - loss: 85.8267 - accuracy: 0.8912 - f1: 0.8913 - val_loss: 316.9647 - val_accuracy: 0.8859 - val_f1: 0.8854
#
# Epoch 00013: val_accuracy did not improve from 0.89130
# Epoch 14/50
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.084294313788414.
#  - 77s - loss: 78.5822 - accuracy: 0.9066 - f1: 0.9066 - val_loss: 210.6417 - val_accuracy: 0.8750 - val_f1: 0.8698
#
# Epoch 00014: val_accuracy did not improve from 0.89130
# Epoch 15/50
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.08345136858522892.
#  - 77s - loss: 88.1451 - accuracy: 0.9093 - f1: 0.9097 - val_loss: 316.6871 - val_accuracy: 0.9022 - val_f1: 0.9010
#
# Epoch 00015: val_accuracy improved from 0.89130 to 0.90217, saving model to  Adam 0.1 binary weights-improvement-15-0.90.hdf5
# Epoch 16/50
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.0826168542355299.
#  - 77s - loss: 114.2017 - accuracy: 0.8898 - f1: 0.8893 - val_loss: 165.1312 - val_accuracy: 0.8859 - val_f1: 0.8750
#
# Epoch 00016: val_accuracy did not improve from 0.90217
# Epoch 17/50
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.08179068222641944.
#  - 77s - loss: 65.5835 - accuracy: 0.9205 - f1: 0.9205 - val_loss: 261.4159 - val_accuracy: 0.8967 - val_f1: 0.8906
#
# Epoch 00017: val_accuracy did not improve from 0.90217
# Epoch 18/50
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.08097277879714966.
#  - 77s - loss: 79.5661 - accuracy: 0.9121 - f1: 0.9125 - val_loss: 178.9769 - val_accuracy: 0.8587 - val_f1: 0.8542
#
# Epoch 00018: val_accuracy did not improve from 0.90217
# Epoch 19/50
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.08016304805874824.
#  - 77s - loss: 48.9074 - accuracy: 0.9344 - f1: 0.9347 - val_loss: 171.1118 - val_accuracy: 0.8859 - val_f1: 0.8854
#
# Epoch 00019: val_accuracy did not improve from 0.90217
# Epoch 20/50
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.0793614162504673.
#  - 639s - loss: 73.9046 - accuracy: 0.9093 - f1: 0.9094 - val_loss: 227.1855 - val_accuracy: 0.8967 - val_f1: 0.8906
#
# Epoch 00020: val_accuracy did not improve from 0.90217
# Epoch 21/50
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.07856780223548412.
#  - 79s - loss: 72.1012 - accuracy: 0.9069 - f1: 0.9069 - val_loss: 357.4013 - val_accuracy: 0.9130 - val_f1: 0.9115
#
# Epoch 00021: val_accuracy improved from 0.90217 to 0.91304, saving model to  Adam 0.1 binary weights-improvement-21-0.91.hdf5
# Epoch 22/50
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.07778212487697601.
#  - 77s - loss: 78.9535 - accuracy: 0.9160 - f1: 0.9160 - val_loss: 270.7275 - val_accuracy: 0.8696 - val_f1: 0.8698
#
# Epoch 00022: val_accuracy did not improve from 0.91304
# Epoch 23/50
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.07700430303812027.
#  - 78s - loss: 56.5048 - accuracy: 0.9303 - f1: 0.9302 - val_loss: 291.2668 - val_accuracy: 0.8859 - val_f1: 0.8854
#
# Epoch 00023: val_accuracy did not improve from 0.91304
# Epoch 24/50
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.07623426295816899.
#  - 78s - loss: 51.3227 - accuracy: 0.9264 - f1: 0.9264 - val_loss: 222.3120 - val_accuracy: 0.8913 - val_f1: 0.8906
#
# Epoch 00024: val_accuracy did not improve from 0.91304
# Epoch 25/50
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.07547192350029945.
#  - 78s - loss: 60.3042 - accuracy: 0.9247 - f1: 0.9247 - val_loss: 363.1012 - val_accuracy: 0.8533 - val_f1: 0.8437
#
# Epoch 00025: val_accuracy did not improve from 0.91304
# Epoch 26/50
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.07471720352768899.
#  - 77s - loss: 66.5586 - accuracy: 0.9188 - f1: 0.9194 - val_loss: 286.0887 - val_accuracy: 0.8641 - val_f1: 0.8646
#
# Epoch 00026: val_accuracy did not improve from 0.91304
# Epoch 27/50
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.07397002927958965.
#  - 78s - loss: 52.3858 - accuracy: 0.9247 - f1: 0.9244 - val_loss: 202.0289 - val_accuracy: 0.9076 - val_f1: 0.9062
#
# Epoch 00027: val_accuracy did not improve from 0.91304
# Epoch 28/50
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.07323032699525356.
#  - 78s - loss: 90.1134 - accuracy: 0.8884 - f1: 0.8879 - val_loss: 208.1940 - val_accuracy: 0.9022 - val_f1: 0.9010
#
# Epoch 00028: val_accuracy did not improve from 0.91304
# Epoch 29/50
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.0724980229139328.
#  - 78s - loss: 69.2216 - accuracy: 0.9163 - f1: 0.9167 - val_loss: 215.3963 - val_accuracy: 0.9022 - val_f1: 0.8958
#
# Epoch 00029: val_accuracy did not improve from 0.91304
# Epoch 30/50
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.07177304327487946.
#  - 78s - loss: 53.2618 - accuracy: 0.9191 - f1: 0.9191 - val_loss: 175.8529 - val_accuracy: 0.9022 - val_f1: 0.8958
# Epoch 00030: val_accuracy did not improve from 0.91304
# Epoch 31/50
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.07105531431734562.
#  - 78s - loss: 55.9808 - accuracy: 0.9306 - f1: 0.9306 - val_loss: 149.0843 - val_accuracy: 0.8967 - val_f1: 0.9010
#
# Epoch 00031: val_accuracy did not improve from 0.91304
# Epoch 32/50
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.07034476228058338.
#  - 78s - loss: 40.4731 - accuracy: 0.9428 - f1: 0.9427 - val_loss: 139.0920 - val_accuracy: 0.9130 - val_f1: 0.9115
#
# Epoch 00032: val_accuracy did not improve from 0.91304
# Epoch 33/50
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.06964131340384483.
#  - 78s - loss: 52.8363 - accuracy: 0.9275 - f1: 0.9278 - val_loss: 219.1957 - val_accuracy: 0.8967 - val_f1: 0.8958
#
# Epoch 00033: val_accuracy did not improve from 0.91304
# Epoch 34/50
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.06894490130245685.
#  - 78s - loss: 75.9730 - accuracy: 0.9107 - f1: 0.9108 - val_loss: 187.6457 - val_accuracy: 0.8424 - val_f1: 0.8490
#
# Epoch 00034: val_accuracy did not improve from 0.91304
# Epoch 35/50
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.06825545221567154.
#  - 77s - loss: 50.9744 - accuracy: 0.9258 - f1: 0.9248 - val_loss: 140.6784 - val_accuracy: 0.8478 - val_f1: 0.8490
#
# Epoch 00035: val_accuracy did not improve from 0.91304
# Epoch 36/50
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.06757289975881577.
#  - 78s - loss: 55.3542 - accuracy: 0.9331 - f1: 0.9330 - val_loss: 132.5904 - val_accuracy: 0.9076 - val_f1: 0.9115
#
# Epoch 00036: val_accuracy did not improve from 0.91304
# Epoch 37/50
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.06689717017114162.
#  - 78s - loss: 46.9018 - accuracy: 0.9261 - f1: 0.9261 - val_loss: 135.8090 - val_accuracy: 0.8370 - val_f1: 0.8385
#
# Epoch 00037: val_accuracy did not improve from 0.91304
# Epoch 38/50
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.066228197067976.
#  - 78s - loss: 49.0120 - accuracy: 0.9264 - f1: 0.9264 - val_loss: 102.4389 - val_accuracy: 0.9076 - val_f1: 0.9062
#
# Epoch 00038: val_accuracy did not improve from 0.91304
# Epoch 39/50
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.06556591406464576.
#  - 78s - loss: 55.9898 - accuracy: 0.9289 - f1: 0.9288 - val_loss: 144.9336 - val_accuracy: 0.8478 - val_f1: 0.8437
#
# Epoch 00039: val_accuracy did not improve from 0.91304
# Epoch 40/50
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.06491025477647781.
#  - 78s - loss: 36.1638 - accuracy: 0.9386 - f1: 0.9386 - val_loss: 101.6823 - val_accuracy: 0.9076 - val_f1: 0.9115
#
# Epoch 00040: val_accuracy did not improve from 0.91304
# Epoch 41/50
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.06426115281879902.
#  - 78s - loss: 53.5470 - accuracy: 0.9233 - f1: 0.9233 - val_loss: 136.9878 - val_accuracy: 0.8913 - val_f1: 0.8958
#
# Epoch 00041: val_accuracy did not improve from 0.91304
# Epoch 42/50
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.06361854180693627.
#  - 78s - loss: 47.8710 - accuracy: 0.9372 - f1: 0.9375 - val_loss: 115.9338 - val_accuracy: 0.8696 - val_f1: 0.8750
#
# Epoch 00042: val_accuracy did not improve from 0.91304
# Epoch 43/50
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.06298235535621644.
#  - 79s - loss: 45.0204 - accuracy: 0.9261 - f1: 0.9261 - val_loss: 114.0887 - val_accuracy: 0.8478 - val_f1: 0.8542
#
# Epoch 00043: val_accuracy did not improve from 0.91304
# Epoch 44/50
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.06235253445804119.
#  - 78s - loss: 49.9066 - accuracy: 0.9331 - f1: 0.9330 - val_loss: 186.4402 - val_accuracy: 0.9076 - val_f1: 0.9010
#
# Epoch 00044: val_accuracy did not improve from 0.91304
# Epoch 45/50
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.06172900903970003.
#  - 78s - loss: 53.8487 - accuracy: 0.9219 - f1: 0.9222 - val_loss: 136.7628 - val_accuracy: 0.8370 - val_f1: 0.8385
#
# Epoch 00045: val_accuracy did not improve from 0.91304
# Epoch 46/50
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.06111172009259462.
#  - 78s - loss: 46.3027 - accuracy: 0.9275 - f1: 0.9278 - val_loss: 120.1533 - val_accuracy: 0.8587 - val_f1: 0.8594
#
# Epoch 00046: val_accuracy did not improve from 0.91304
# Epoch 47/50
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.06050060123205185.
#  - 79s - loss: 50.5632 - accuracy: 0.9303 - f1: 0.9306 - val_loss: 140.2137 - val_accuracy: 0.8967 - val_f1: 0.8906
#
# Epoch 00047: val_accuracy did not improve from 0.91304
# Epoch 48/50
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.05989559344947338.
#  - 80s - loss: 34.3617 - accuracy: 0.9456 - f1: 0.9458 - val_loss: 177.6333 - val_accuracy: 0.8370 - val_f1: 0.8385
#
# Epoch 00048: val_accuracy did not improve from 0.91304
# Epoch 49/50
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.05929663773626089.
#  - 80s - loss: 43.0279 - accuracy: 0.9275 - f1: 0.9271 - val_loss: 147.5466 - val_accuracy: 0.8750 - val_f1: 0.8802
#
# Epoch 00049: val_accuracy did not improve from 0.91304
# Epoch 50/50
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.05870367139577866.
#  - 78s - loss: 45.8889 - accuracy: 0.9275 - f1: 0.9275 - val_loss: 310.4859 - val_accuracy: 0.7609 - val_f1: 0.7656
#
# Epoch 00050: val_accuracy did not improve from 0.91304

# %%
# evaluate the network and show a classification report
print("[INFO] evaluating network...")
predictions = model.predict(testX, batch_size=BATCH_SIZE)
print(classification_report(testY.argmax(axis=1),
	predictions.argmax(axis=1), target_names=CLASSES))
# Out:
# [INFO] evaluating network...
#               precision    recall  f1-score   support
#
#     abnormal       0.93      0.74      0.82       138
#       normal       0.51      0.83      0.63        46
#
#     accuracy                           0.76       184
#    macro avg       0.72      0.78      0.73       184
# weighted avg       0.82      0.76      0.78       184

# %%
# construct a plot that plots and saves the training history
N = np.arange(0, EPOCHS)
plt.style.use("ggplot")
plt.figure()
plt.plot(N, H.history["loss"], label="train_loss")
plt.plot(N, H.history["val_loss"], label="val_loss")
#plt.plot(N, H.history["accuracy"], label="train_acc")
#plt.plot(N, H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss ")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend(loc="lower left")
plt.savefig(TRAINING_PLOT_PATH)

# %%
# construct a plot that plots and saves the training history
N = np.arange(0, EPOCHS)
plt.style.use("ggplot")
plt.figure()
#plt.plot(N, H.history["loss"], label="train_loss")
#plt.plot(N, H.history["val_loss"], label="val_loss")
plt.plot(N, H.history["accuracy"], label="train_acc")
plt.plot(N, H.history["val_accuracy"], label="val_acc")
plt.title("Training Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Accuracy")
plt.legend(loc="lower left")
plt.savefig(TRAINING_PLOT_ACC_PATH)

# %%
# # plot the learning rate history
# N = np.arange(0, len(clr.history["lr"]))
# plt.figure()
# plt.plot(N, clr.history["lr"])
# plt.title("Cyclical Learning Rate (CLR)")
# plt.xlabel("Training Iterations")
# plt.ylabel("Learning Rate")
# plt.savefig(CLR_PLOT_PATH)
